# %% [markdown]
# # Foreign Key Processing

# %%
# ! py -m pip install networkx
# ! py -m pip install thefuzz

# %%
import pandas as pd
import networkx as nx
from thefuzz import fuzz
from thefuzz import process
import numpy as np

# %%
path = 'C:\\Users\\mounsl\\OneDrive - Idaho National Laboratory\\Documents - GRP-Agree Data Assessment Team\\Security\\3. Data and Modeling\\Data Dictionary\\IFACTS\\' #path to where files for the database are kept
database = 'IFACTS'
date = '20240515'

# %%
raw_FKs = pd.read_excel(path+database+'_FKs_'+date+'.xlsx')

# %%
raw_FKs
# Out:
#     SchemaName                       TableName      ReferencedTable  \
# 0          dbo               aspnet_Membership  aspnet_Applications
# 1          dbo               aspnet_Membership         aspnet_Users
# 2          dbo                    aspnet_Paths  aspnet_Applications
# 3          dbo  aspnet_PersonalizationAllUsers         aspnet_Paths
# 4          dbo   aspnet_PersonalizationPerUser         aspnet_Paths
# ..         ...                             ...                  ...
# 111        dbo                datUserReportCol        datUserReport
# 112        dbo                datUserReportUdf         datReportUdf
# 113        dbo                datUserReportUdf        datUserReport
# 114        dbo                       luCountry        luCountryType
# 115        dbo                      luSoftware       luSoftwareType
#
#           ColumnName                            FK_name ReferencedColumn
# 0      ApplicationId     FK__aspnet_Me__Appli__1FD8A9E3    ApplicationId
# 1             UserId     FK__aspnet_Me__UserI__20CCCE1C           UserId
# 2      ApplicationId     FK__aspnet_Pa__Appli__51700577    ApplicationId
# 3             PathId     FK__aspnet_Pe__PathI__5728DECD           PathId
# 4             PathId     FK__aspnet_Pe__PathI__5AF96FB1           PathId
# ..               ...                                ...              ...
# 111    UserReport_ID  FK_datUserReportCol_datUserReport    UserReport_ID
# 112     ReportUdf_ID   FK_datUserReportUdf_datReportUdf     ReportUdf_ID
# 113    UserReport_ID  FK_datUserReportUdf_datUserReport    UserReport_ID
# 114   CountryType_ID         FK_luCountry_luCountryType   CountryType_ID
# 115  SoftwareType_ID       FK_luSoftware_luSoftwareType  SoftwareType_ID
#
# [116 rows x 6 columns]

# %%
raw_FKs[['TableName','ColumnName','ReferencedColumn','ReferencedTable']].head(50)
# Out:
#                          TableName                ColumnName  \
# 0                aspnet_Membership             ApplicationId
# 1                aspnet_Membership                    UserId
# 2                     aspnet_Paths             ApplicationId
# 3   aspnet_PersonalizationAllUsers                    PathId
# 4    aspnet_PersonalizationPerUser                    PathId
# 5    aspnet_PersonalizationPerUser                    UserId
# 6                   aspnet_Profile                    UserId
# 7                     aspnet_Roles             ApplicationId
# 8                     aspnet_Users             ApplicationId
# 9              aspnet_UsersInRoles                    RoleId
# 10             aspnet_UsersInRoles                    UserId
# 11                  brRequest_Area        ApprRequestForm_ID
# 12                  brRequest_Area                   Area_ID
# 13                  brRequest_Area                 Escort_ID
# 14              brRequest_Software        ApprRequestForm_ID
# 15              brRequest_Software               Software_ID
# 16           brRequest_StateAction        ApprRequestForm_ID
# 17           brRequest_StateAction            StateAction_ID
# 18           brRequest_SubjectCode        ApprRequestForm_ID
# 19           brRequest_SubjectCode               SubjCode_ID
# 20               brREVRequest_Area        ApprRequestForm_ID
# 21               brREVRequest_Area                   Area_ID
# 22               brREVRequest_Area                 Escort_ID
# 23           brREVRequest_Software        ApprRequestForm_ID
# 24           brREVRequest_Software               Software_ID
# 25        brREVRequest_StateAction        ApprRequestForm_ID
# 26        brREVRequest_StateAction            StateAction_ID
# 27        brREVRequest_SubjectCode        ApprRequestForm_ID
# 28        brREVRequest_SubjectCode               SubjCode_ID
# 29            brUser_Role_RespArea               RespArea_ID
# 30                datAddtSubmitter        ApprRequestForm_ID
# 31              datApprRequestForm   Closeout_VisitStatus_ID
# 32              datApprRequestForm                Company_ID
# 33              datApprRequestForm  ExpeditedRequestState_ID
# 34              datApprRequestForm    FVAInteractionType1_ID
# 35              datApprRequestForm    FVAInteractionType2_ID
# 36              datApprRequestForm            PurposeCode_ID
# 37              datApprRequestForm         SensitiveTopic_ID
# 38              datApprRequestForm                  State_ID
# 39                         datArea               AreaType_ID
# 40              datAwareIndividual        ApprRequestForm_ID
# 41                       datEscort        ApprRequestForm_ID
# 42            datHistoricalSecPlan         ApprRequestFormId
# 43            datHistoricalSecPlan        HistoricalDataType
# 44          datPrevisitBriefingLog        ApprRequestForm_ID
# 45                 datReportTblCol          ReportColType_ID
# 46                 datReportTblCol              ReportTbl_ID
# 47      datRequest_FN_FamilyMember             BirthCitiz_ID
# 48      datRequest_FN_FamilyMember           BirthCountry_ID
# 49      datRequest_FN_FamilyMember           Relationship_ID
#
#             ReferencedColumn          ReferencedTable
# 0              ApplicationId      aspnet_Applications
# 1                     UserId             aspnet_Users
# 2              ApplicationId      aspnet_Applications
# 3                     PathId             aspnet_Paths
# 4                     PathId             aspnet_Paths
# 5                     UserId             aspnet_Users
# 6                     UserId             aspnet_Users
# 7              ApplicationId      aspnet_Applications
# 8              ApplicationId      aspnet_Applications
# 9                     RoleId             aspnet_Roles
# 10                    UserId             aspnet_Users
# 11        ApprRequestForm_ID       datApprRequestForm
# 12                   Area_ID                  datArea
# 13                 Escort_ID                datEscort
# 14        ApprRequestForm_ID       datApprRequestForm
# 15               Software_ID               luSoftware
# 16        ApprRequestForm_ID       datApprRequestForm
# 17            StateAction_ID            luStateAction
# 18        ApprRequestForm_ID       datApprRequestForm
# 19               SubjCode_ID           luSubjectCodes
# 20        ApprRequestForm_ID    datREVApprRequestForm
# 21                   Area_ID                  datArea
# 22                 Escort_ID             datREVEscort
# 23        ApprRequestForm_ID    datREVApprRequestForm
# 24               Software_ID               luSoftware
# 25        ApprRequestForm_ID    datREVApprRequestForm
# 26            StateAction_ID            luStateAction
# 27        ApprRequestForm_ID    datREVApprRequestForm
# 28               SubjCode_ID           luSubjectCodes
# 29               RespArea_ID               luRespArea
# 30        ApprRequestForm_ID       datApprRequestForm
# 31            VisitStatus_ID            luVisitStatus
# 32                Company_ID                luCompany
# 33  ExpeditedRequestState_ID  luExpeditedRequestState
# 34        InteractionType_ID        luInteractionType
# 35        InteractionType_ID        luInteractionType
# 36            PurposeCode_ID            luPurposeCode
# 37         SensitiveTopic_ID         luSensitiveTopic
# 38                  State_ID                  luState
# 39               AreaType_ID               luAreaType
# 40        ApprRequestForm_ID       datApprRequestForm
# 41        ApprRequestForm_ID       datApprRequestForm
# 42        ApprRequestForm_ID       datApprRequestForm
# 43        HistoricalDataType   enumHistoricalDataType
# 44        ApprRequestForm_ID       datApprRequestForm
# 45          ReportColType_ID          luReportColType
# 46              ReportTbl_ID             datReportTbl
# 47                Country_ID                luCountry
# 48                Country_ID                luCountry
# 49           Relationship_ID           luRelationship

# %% [markdown]
# ## Analysis with NetworkX
#
# Documentation: https://networkx.org/documentation/stable/reference/index.html

# %%
edgelist = raw_FKs[['TableName', 'ReferencedTable']]
edgelist.to_csv(database+'_edgelist.csv', index=False, header=False)
fk_graph = nx.read_edgelist(database+'_edgelist.csv', delimiter=',',create_using=nx.DiGraph)
fk_graph.number_of_nodes()
fk_graph.number_of_edges()
nx.is_directed_acyclic_graph(fk_graph)
nx.is_weakly_connected(fk_graph)
nx.number_weakly_connected_components(fk_graph)
for c in nx.weakly_connected_components(fk_graph):
    print(len(c), ':', c)

# %% [markdown]
# ## Possible Uninforced Foreign Keys with Fuzzy Matching

# %%
raw_cols = pd.read_excel(path+'Working\\'+database+'_RawTableChars.xlsx', usecols=['TableName', 'ColumnName'])

# %%
raw_cols
# Out:
#                 TableName              ColumnName
# 0     aspnet_Applications           ApplicationId
# 1     aspnet_Applications         ApplicationName
# 2     aspnet_Applications             Description
# 3     aspnet_Applications  LoweredApplicationName
# 4       aspnet_Membership           ApplicationId
# ...                   ...                     ...
# 1400          sysdiagrams              definition
# 1401          sysdiagrams              diagram_id
# 1402          sysdiagrams                    name
# 1403          sysdiagrams            principal_id
# 1404          sysdiagrams                 version
#
# [1405 rows x 2 columns]

# %%
def extract_matches(cols, existing_relationships):
    cols["match results"] = cols['ColumnName'].apply(lambda x: process.extract(x, cols['ColumnName'], scorer=fuzz.ratio))
    new_rows = []
    for index, row in cols.iterrows():
        for result in row['match results']:
            new_row = {'TableName':row['TableName'],
                    'ColumnName':row['ColumnName'],
                    'MatchColumn':result[0],
                    'MatchRatio':result[1],
                    'MatchTable':cols.iloc[result[2]]['TableName']}
            new_rows.append(new_row)
    new_df = pd.DataFrame(new_rows, columns=['TableName','ColumnName','MatchColumn','MatchRatio','MatchTable'])
    new_df = new_df[(new_df['TableName'] != new_df['MatchTable'])]
    new_df['combo'] = new_df['TableName']+','+new_df['ColumnName']+' to '+new_df['MatchTable']+','+new_df['MatchColumn']
    new_df = new_df[(~new_df['combo'].isin(existing_relationships))&(new_df['MatchRatio']>80)].drop(columns=['combo'])
    return new_df[['TableName','ColumnName','MatchColumn','MatchTable','MatchRatio']]
        
def search_term(df, term, regex=False):
    results_df = df[(df['MatchName'].str.contains(term,case=False,regex=regex))|(df['ColumnName'].str.contains(term,case=False, regex=regex))]
    return results_df

# %%
fks = raw_FKs

# %%
### XXX True deduping needs to disregard direction of relationship: merge TableName and ReferencedTable ColumnName and ReferencedColumn THEN dedup
fks['dir1'] = fks['TableName']+','+fks['ColumnName']+' to '+fks['ReferencedTable']+','+fks['ReferencedColumn']
fks['dir2'] = fks['ReferencedTable']+','+fks['ReferencedColumn']+' to '+fks['TableName']+','+fks['ColumnName']

# %%
all_relationships = pd.concat([fks['dir1'],fks['dir2']])

# %%
all_relationships
# Out:
# 0      aspnet_Membership,ApplicationId to aspnet_Appl...
# 1        aspnet_Membership,UserId to aspnet_Users,UserId
# 2      aspnet_Paths,ApplicationId to aspnet_Applicati...
# 3      aspnet_PersonalizationAllUsers,PathId to aspne...
# 4      aspnet_PersonalizationPerUser,PathId to aspnet...
#                              ...
# 111    datUserReport,UserReport_ID to datUserReportCo...
# 112    datReportUdf,ReportUdf_ID to datUserReportUdf,...
# 113    datUserReport,UserReport_ID to datUserReportUd...
# 114    luCountryType,CountryType_ID to luCountry,Coun...
# 115    luSoftwareType,SoftwareType_ID to luSoftware,S...
# Length: 232, dtype: object

# %%
len(all_relationships)
# Out:
# 232

# %%
match_df = extract_matches(raw_cols,all_relationships)

# %% [markdown]
# ### Custom Munging

# %%
excluded_tables = ['aspnet_PersonalizationAllUsers', 'aspnet_PersonalizationPerUser', 'aspnet_Paths', 'aspnet_Users', 'aspnet_Profile', 'aspnet_Roles', 'aspnet_Applications', 'aspnet_UsersInRoles', 'aspnet_Membership','datReportTbl', 'datReportTblCol', 'luReportColType', 'datUserReportUdf', 'datUserReportCol', 'datUserReport', 'datReportUdf']

# %%
match_df = match_df[(~match_df['TableName'].isin(excluded_tables))&(~match_df['MatchTable'].isin(excluded_tables))]

# %%
match_df = match_df[(~match_df['TableName'].str.contains('LOG'))&(~match_df['MatchTable'].str.contains('LOG'))]

# %%
match_df = match_df[(~match_df['TableName'].str.startswith('br'))&(~match_df['MatchTable'].str.startswith('br'))]

# %%
match_df = match_df[(~match_df['TableName'].str.startswith('lu'))]

# %%
match_df = match_df[(~match_df['TableName'].str.contains('REV'))&(~match_df['MatchTable'].str.contains('REV'))]

# %%
match_df.to_csv('IFACTS_FK_processing_test.csv',index=False)
#match_df.to_excel(path+'Working\\'+database+'_Possible_FKs.xlsx',index=False)

# %%
raw_FKs[(raw_FKs['TableName']=='aspnet_Applications')|(raw_FKs['ReferencedTable']=='aspnet_Applications')][['TableName','ReferencedTable','ColumnName','ReferencedColumn']]
# Out:
#            TableName      ReferencedTable     ColumnName ReferencedColumn
# 0  aspnet_Membership  aspnet_Applications  ApplicationId    ApplicationId
# 2       aspnet_Paths  aspnet_Applications  ApplicationId    ApplicationId
# 7       aspnet_Roles  aspnet_Applications  ApplicationId    ApplicationId
# 8       aspnet_Users  aspnet_Applications  ApplicationId    ApplicationId

# %% [markdown]
# ## Possible External Relationships

# %%
# SNumber
# Dates
# Facilities/Buildings
#

# %% [markdown]
# ### Custom Analysis

# %% [markdown]
# # TRAIN Analysis

# %%
train = pd.read_excel('C:\\Users\\mounsl\\OneDrive - Idaho National Laboratory\\Documents - GRP-Agree Data Assessment Team\\Training\\3. Data & Modeling\\Data Dictionary\\Working\\TRAIN_PKFK.xlsx')

# %%
train#[train['TABLENAME']]
# Out:
#              TABLENAME            COLNAME  Referenced Table Referenced Column  \
# 0    ADMINISTRATOR_ORG        CLASS_ADMIN               NaN               NaN
# 1    ADMINISTRATOR_ORG        CONTRACT_ID  PRIME_CONTRACTOR       CONTRACT_ID
# 2    ADMINISTRATOR_ORG        EMP_SSN_NUM          EMPLOYEE       EMP_SSN_NUM
# 3    ADMINISTRATOR_ORG           ORG_CODE               ORG          ORG_CODE
# 4    ADMINISTRATOR_ORG       ORG_ENROLLER               NaN               NaN
# ..                 ...                ...               ...               ...
# 415            READING  RE_READ_INTVL_MTH               NaN               NaN
# 416            READING      SRCE_REQ_DESC               NaN               NaN
# 417            READING      TRAIN_DUR_HRS               NaN               NaN
# 418            READING        UPDATE_DATE               NaN               NaN
# 419            READING         UPDATE_UID               NaN               NaN
#
#      PK_ordinal_position
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 415                  NaN
# 416                  NaN
# 417                  NaN
# 418                  NaN
# 419                  NaN
#
# [420 rows x 5 columns]

# %%
no_reference = train[(~train['Referenced Table'].isin(train['TABLENAME'].unique().tolist()))&(~train['Referenced Table'].isna())]

# %%
no_reference
# Out:
#                TABLENAME           COLNAME  Referenced Table  \
# 1      ADMINISTRATOR_ORG       CONTRACT_ID  PRIME_CONTRACTOR
# 18           ATTEND_TEST   INSTR_TYPE_CODE        INSTR_TYPE
# 40                 CLASS   INSTR_TYPE_CODE        INSTR_TYPE
# 47                 CLASS         VEND_CODE              VEND
# 89                COURSE       CONTRACT_ID  PRIME_CONTRACTOR
# 101               COURSE     FACILITY_CODE          FACILITY
# 104               COURSE   INSTR_TYPE_CODE  INSTRUCTION_TYPE
# 111               COURSE        REPORT_CAT         TRAIN_CAT
# 121               COURSE           TRM_CAT           TRM_CAT
# 132  COURSE_WAITING_LIST   INSTR_TYPE_CODE  INSTRUCTION_TYPE
# 136        EMP_ADMIN_DOC    ADMIN_DOC_CODE         ADMIN_DOC
# 179         EMP_QLF_CRIT      CRIT_SETTING  INSTRUCTION_TYPE
# 183          EMP_READING       CONTRACT_ID  PRIME_CONTRACTOR
# 193             EMPLOYEE         AREA_CODE             AREAS
# 199             EMPLOYEE           CO_CODE           COMPANY
# 221             EMPLOYEE     FACILITY_CODE          FACILITY
# 230             EMPLOYEE     PRIME_CO_CODE           COMPANY
# 231             EMPLOYEE  PRIME_CONTRACTOR  PRIME_CONTRACTOR
# 252                  JOB          FUNCTION       JC_FUNCTION
# 258                  JOB          LOCATION          LOCATION
# 261                  JOB          POSITION       JC_POSITION
# 267             JOB_PROG         PROG_CODE           PROGRAM
# 269                  ORG       CONTRACT_ID  PRIME_CONTRACTOR
# 278              PROG_AF   ADMIN_FORM_CODE         ADMIN_DOC
# 280              PROG_AF         PROG_CODE           PROGRAM
# 282          PROG_COURSE   INSTR_TYPE_CODE  INSTRUCTION_TYPE
# 284          PROG_COURSE         PROG_CODE           PROGRAM
# 286             PROG_QLF         PROG_CODE           PROGRAM
# 292         PROG_READING         PROG_CODE           PROGRAM
# 301        QUAL_CRITERIA         CRIT_CODE         ADMIN_DOC
# 306        QUAL_CRITERIA      CRIT_SETTING  INSTRUCTION_TYPE
# 353            STRUCTURE         AREA_CODE             AREAS
# 376                 TEST   INSTR_TYPE_CODE  INSTRUCTION_TYPE
#
#            Referenced Column  PK_ordinal_position
# 1                CONTRACT_ID                  NaN
# 18           INSTR_TYPE_CODE                  3.0
# 40           INSTR_TYPE_CODE                  NaN
# 47                 VEND_CODE                  NaN
# 89               CONTRACT_ID                  NaN
# 101            FACILITY_CODE                  NaN
# 104    INSTRUCTION_TYPE_CODE                  3.0
# 111           TRAIN_CAT_CODE                  NaN
# 121               TRM_CAT_ID                  NaN
# 132    INSTRUCTION_TYPE_CODE                  2.0
# 136           ADMIN_DOC_CODE                  2.0
# 179    INSTRUCTION_TYPE_CODE                  5.0
# 183              CONTRACT_ID                  5.0
# 193                AREA_CODE                  NaN
# 199                  CO_CODE                  NaN
# 221            FACILITY_CODE                  NaN
# 230                  CO_CODE                  NaN
# 231  PRIME_CONTRACTOR_ABBREV                  NaN
# 252                 FUNCTION                  NaN
# 258                 LOCATION                  NaN
# 261                 POSITION                  NaN
# 267                PROG_CODE                  2.0
# 269              CONTRACT_ID                  NaN
# 278           ADMIN_DOC_CODE                  2.0
# 280                PROG_CODE                  1.0
# 282    INSTRUCTION_TYPE_CODE                  3.0
# 284                PROG_CODE                  1.0
# 286                PROG_CODE                  1.0
# 292                PROG_CODE                  1.0
# 301           ADMIN_DOC_CODE                  NaN
# 306    INSTRUCTION_TYPE_CODE                  NaN
# 353                AREA_CODE                  NaN
# 376    INSTRUCTION_TYPE_CODE                  2.0

# %%
no_reference['Referenced Table'].unique().tolist()
# Out:
# ['PRIME_CONTRACTOR',
#  'INSTR_TYPE',
#  'VEND',
#  'FACILITY',
#  'INSTRUCTION_TYPE',
#  'TRAIN_CAT',
#  'TRM_CAT',
#  'ADMIN_DOC',
#  'AREAS',
#  'COMPANY',
#  'JC_FUNCTION',
#  'LOCATION',
#  'JC_POSITION',
#  'PROGRAM']
