# %% [markdown]
# # Key Processing

# %%
import pandas as pd
import glob
import re
import os.path
import numpy as np
from openpyxl import load_workbook

# %%
databases = ['Asset Suite', 'Archibus', 'COBRA','EDMS','FIS','IPS','P6','PID','Site People','Time Billing']
path = 'C:\\Users\\\mounsl\\OneDrive - Idaho National Laboratory\\Documents - GRP-Agree Data Assessment Team\\Data Assessment Taxonomy\\PK-FK files\\' #path to where files for the database are kept

# %% [markdown]
# ## Key Merging

# %%
dd_gloss = pd.read_excel('Data Elements Taxonomy_copy.xlsx', sheet_name='Data Dictionary')  ## Data to merge with
writer = pd.ExcelWriter('Data Elements Taxonomy_PKFK.xlsx', engine='openpyxl', mode = 'a', if_sheet_exists='overlay') ## Pre-formatted to receive output
clean_PKs = pd.DataFrame()
clean_FKs = pd.DataFrame()
for database in databases:    
    #PKs
    if os.path.isfile(path+database+'-PKs.xlsx'):
        # print(database)
        raw_PKs = pd.read_excel(path+database+'-PKs.xlsx')
        raw_PKs = raw_PKs.rename(columns={'TableName':'TABLENAME','ColumnName':'COLNAME','ORDINAL_POSITION':'Primary Key'}).drop(columns=['SchemaName','PK_name'])
        raw_PKs['System'] = database
        raw_PKs['TABLENAME'] = raw_PKs['TABLENAME'].str.strip()
        raw_PKs['COLNAME'] = raw_PKs['COLNAME'].str.strip()
        raw_PKs = raw_PKs[['System','TABLENAME','COLNAME','Primary Key']]
        clean_PKs = pd.concat([clean_PKs,raw_PKs])

    #FKS
    if os.path.isfile(path+database+'-FKs.xlsx'):
        raw_FKs = pd.read_excel(path+database+'-FKs.xlsx')
        raw_FKs = raw_FKs.rename(columns={'TableName':'TABLENAME','ColumnName':'COLNAME'}).drop(columns=['SchemaName','FK_name'])
        raw_FKs['System'] = database
        raw_FKs['TABLENAME'] = raw_FKs['TABLENAME'].str.strip()
        raw_FKs['COLNAME'] = raw_FKs['COLNAME'].str.strip()
        clean_FKs = pd.concat([clean_FKs,raw_FKs])

dd_gloss['System'] = dd_gloss['System'].str.strip()
dd_gloss['TABLENAME'] = dd_gloss['TABLENAME'].str.strip()
dd_gloss['COLNAME'] = dd_gloss['COLNAME'].str.strip()
dd_gloss = dd_gloss.merge(clean_PKs, on=['System','TABLENAME','COLNAME'], how='left')
dd_gloss = dd_gloss.merge(clean_FKs, on=['System','TABLENAME','COLNAME'], how='left')

# %%
dd_gloss.to_excel(writer, sheet_name = 'Data Dictionary', index=False)
writer.close()

# %% [markdown]
# # Asset Suite Key "Query"

# %%
# as_path = 'c:\\Users\\mounsl\\OneDrive - Idaho National Laboratory\\Documents - GRP-Agree Data Assessment Team\\Asset Suite\\Working documents - Start here\\'
# files = glob.glob(as_path + 'DataDictionary*.xlsx')
# as_pks = pd.DataFrame(columns=['Dictionary','TableName','ColumnName','ORDINAL_POSITION','PK_name'])
# table_count = 0
# for file in files:
#     print(file)
#     workbook = pd.read_excel(file, sheet_name=None, keep_default_na = False)
#     for key, df in workbook.items():        
#         if '-' in key:
#             print(key)
#             table_count += 1
#             tableName = re.sub(' ', '',key).split('-')[-1]
#             index_rows = df[(df.iloc[:,0].str.contains('INDEX', na=False))&(df.iloc[:,0].str.contains('CREATE', na=False))].index
            
#             for rownum in index_rows:
#                 pk_name = re.search('(?<= INDEX )(\S+)',df.iloc[rownum,0])[0]
#                 print(pk_name)
#                 pks = ''
#                 i=rownum+1
#                 while df.iloc[i,0]!='':
#                     pks = pks+re.sub('[() ]', '', df.iloc[i,0])
#                     i += 1
#                 # print(pks[0:len(pks)]) 
#                 pk_list = pks.split(',')
#                 j = 1
#                 for pk in pk_list:
#                     as_pks.loc[len(as_pks)] = {'Dictionary':file.split('_',1)[1], 'TableName':tableName,'ColumnName':pk,'ORDINAL_POSITION':j, 'PK_name':pk_name}
#                     j+=1
# as_pks['SchemaName'] = ''

# as_pks = as_pks.drop_duplicates()
# Out:
# c:\Users\mounsl\OneDrive - Idaho National Laboratory\Documents - GRP-Agree Data Assessment Team\Asset Suite\Working documents - Start here\DataDictionary_AT.xlsx
# Action Request Type - TIDACATT
# BASE.TIIACATT
# Action Request Activ - TIDARACT
# BASE.TIIARACT
# Action Request Cmts - TIDARCOM
# BASE.TIIARCOM
# Action Request Docs - TIDARDOC
# BASE.TIIARDOC
# Action Rqst Events - TIDAREVT
# BASE.TIIAREVT
# Action Rqst Keywords - TIDARKEY
# BASE.TIIARKEY
# Action Request Master- TIDARMST
# BASE.TIIARMS1
# BASE.TIIARMST
# AR Contacts - TIDARNOT
# BASE.TIIARNOT
# AR Type - TIDARTYP
# BASE.TIIARTYP
# Assignment Master - TIDASMST
# BASE.TIIASMST
# BASE.TIIASMS2
# Assignment Notes - TIDASNOT
# BASE.TIIASNOT
# AT Equipment - TIDATEQN
# BASE.TIIATEQN
# AT Stock Code - TIDATMAT
# BASE.TIIATMAT
# AT Stock Code - TIDATPHY
# BASE.TIIATPHY
# AT Status Cmp Code - TIDATSRC
# BASE.TIIATSRC
# AT Status Tracking - TIDATSTR
# BASE.TIIATSTR
# c:\Users\mounsl\OneDrive - Idaho National Laboratory\Documents - GRP-Agree Data Assessment Team\Asset Suite\Working documents - Start here\DataDictionary_EC.xlsx
# Engn Chg Request - TIDERREQ
# BASE.TIIERREQ
# Eng Chg Rqst Trking  - TIDERSTR
# BASE.TIIERSTR
# EC Rqst Affected Doc -TIDERADL
# BASE.TIIERADL
# EC Rqst Affected Equip-TIDERAEL
# BASE.TIIERAEL
# Engineering Change - TIDENCHG
# BASE.TIIENCHG
# Eng Chg Type - TIDECTYP
# BASE.TIIECTYP
# Eng Chg Status Trkg - TIDENSTR
# BASE.TIIENSTR
# Eng Chg Affected Doc - TIDENADL
# BASE.TIIENADL
# Eng Chg Affected Equ - TIDENAEL
# BASE.TIIENAEL
# Eng Chg Affected BOM -TIDENBOM
# BASE.TIIENBOM
# Eng Chg Affected Cat - TIDENCAT
# BASE.TIIENCAT
# Eng Chg Equip ID Req - TIDENIDC
# BASE.TIIENIDC
# Eng Chg Milestone - TIDENMIL
# BASE.TIIENMIL
# Eng Chg System - TIDENSYS
# BASE.TIIENSYS
# Eng Chg Unit - TIDENUN
# BASE.TIIENUN
# Passport Xref - TIDPXREF
# BASE.TIIPXREF
# Binary Linked Object - TIDOBLOB
# BASE.TIIOBLO1
# BASE.TIIOBLO2
# Generic Notes Owner - TIDTPCOL
# BASE.TIITPCOL
# c:\Users\mounsl\OneDrive - Idaho National Laboratory\Documents - GRP-Agree Data Assessment Team\Asset Suite\Working documents - Start here\DataDictionary_MEL.xlsx
# Accting Distribution - TIDACDST
# BASE.TIIACDST
# Attribute Info - TIDATTRB
# BASE.TIIATTRB
# Area Code Table - TIDCVARE
# BASE.TIICVARE
# Division Code Table - TIDCVDIV
# BASE.TIICVDIV
# Failure Mode - TIDCVFMD
# BASE.TIICVFMD
# Manufact Code Table - TIDCVMFR
# BASE.TIICVMFR
# Root Cause Code - TIDCVRCS
# BASE.TIICVRCS
# Sub Type Code - TIDCVSUB
# BASE.TIICVSUB
# System Code Table - TIDCVSYS
# BASE.TIICVSYS
# Equip Type Code - TIDCVTYP
# BASE.TIICVTYP
# Personnel Master - TIDEMPLO
# BASE.TIIEMPLO
# FacilityUnit Route -TIDLBSTP
# BASE.TIILBST2
# BASE.TIILBSTP
# Facility Unit Routing -TIDLBRTE
# BASE.TIILBRTE
# Location - TIDLOCAT
# BASE.TIILOCAT
# Facility Master - TIDFAMST
# BASE.TIIFAMS1
# Work Item Definitiopn -TIDWIDEF
# BASE.TIIWIDEF
# Work Item Notes -TIDWINTE
# BASE.TIIWINTE
# Generic Notes -TIDTPCOL
# BASE.TIITPCOL
# Facility Shutdown - TIDFASHT
# BASE.TIIFASHT
# Unit Master Data - TIDUNMST
# BASE.TIIUNMST
# Equip History Analysis-TIDEANLY
# BASE.TIIEANLY
# Equip History RsnRoot-TIDEARSN
# BASE.TIIEARSN
# Approved Model List - TIDECAML
# BASE.TIIECAM1
# Equip Drawing Data - TIDECDRW
# BASE.TIIECDR2
# EC Information - TIDECEQN
# BASE.TIIECEQN
# Function Equip Group- TIDECFEG
# BASE.TIIECFEG
# EC Header - TIDECHDR
# BASE.TIIECHDR
# Equip ID Chg Request - TIDECIDC
# BASE.TIIECIDC
# Equip Key Req - TIDECKEY
# BASE.TIIECKEY
# Configuration History -TIDECHST
# BASE.TIIECHST
# Equipment Location - TIDECLOC
# BASE.TIIECLOC
# EC Nuclear Info - TIDECNUC
# BASE.TIIECNUC
# EC Physical Entity - TIDECPHY
# BASE.TIIECPH1
# BASE.TIIECPH3
# PM Parameters - TIDECPMS
# BASE.TIIECPMS
# PMPredefined History - TIDPMHST
# BASE.TIIPMHS1
# BASE.TIIPMHST
# PM Due Date History - TIDPMDDH
# BASE.TIIPMDDH
# PM Forecast - TIDPMFUT
# BASE.TIIPMFU1
# BASE.TIIPMFU2
# PM Item XREF - TIDPMREF
# BASE.TIIPMRE1
# PM RQ Relationship - TIDPMREL
# BASE.TIIPMREL
# PM Pre Work List -TIDPDWKL
# BASE.TIIPDWK2
# PM Pre Work Request -TIDPDWLR
# BASE.TIIPDWL2
# EC Parameter Value - TIDECPV
# BASE.TIIECPV
# Equip Relationship - TIDECREL
# BASE.TIIECRE1
# Equip Reservations - TIDECRSV
# BASE.TIIECRSV
# Equip Status Tracking -TIDECSTR
# BASE.TIIECSTR
# Equip Group - TIDEQGRP
# BASE.TIIEQGRP
# Equip Operating Status-TIDEQOSH
# BASE.TIIEQOS1
# EC Requirements - TIDEQREQ
# BASE.TIIEQREQ
# Equip Series Summary - TIDEQSUM
# BASE.TIIEQSUM
# BOM Item Number - TIDBOITM
# BASE.TIIBOITM
# Bill of Materials - TIDBOM
# BASE.TIIBOM
# BOM EC Specific - TIDBOMEC
# BASE.TIIBOMEC
# BOM Where Used - TIDBOWHR
# BASE.TIIBOWHR
# Specific Part Ident - TIDSPIN
# BASE.TIISPIN
# c:\Users\mounsl\OneDrive - Idaho National Laboratory\Documents - GRP-Agree Data Assessment Team\Asset Suite\Working documents - Start here\DataDictionary_PE.xlsx
# Catalog Facility Cmts-TIDCACOF
# BASE.TIICACOF
# Catalog Comments -TIDCACOM
# BASE.TIICACOM
# Catalog Facility Data- TIDCAFAC
# BASE.TIICAFAC
# Catalog MFR-Part No-TIDCAMFR
# BASE.TIICAMF2
# Catalog Master - TIDCAMST
# BASE.TIICAMS1
# Catalog ID QLevel - TIDCAQLV
# BASE.TIICAQLV
# Catalog Tech Stds - TIDCASTD
# BASE.TIICASTD
# Catalog Facility Std - TIDCASTF
# BASE.TIICASTF
# PE Request Master - TIDPERQM
# BASE.TIIPERQM
# Procurement Rqmts - TIDPPREQ
# BASE.TIIPPREQ
# Comm Grade Dedication- TIDPECGD
# BASE.TIIPECGD
# Design Basis Document- TIDPEDBD
# BASE.TIIPEDBD
# PE Qstn Group - TIDPEGRP
# BASE.TIIPEGRP
# IEEE Config - TIDPEIEE
# BASE.TIIPEIEE
# PE MFR-Part Number - TIDPEMFR
# BASE.TIIPEMFR
# PE Request Remarks - TIDPERMK
# BASE.TIIPERMK
# Safety Basis Sum- TIDPSBAS
# BASE.TIIPSBAS
# Stds and Procedures - TIDSPMST
# BASE.TIISPMST
# OLE Document Master - TIDPOLE
# BASE.TIIPOLE
# Doc Reference - TIDDOCRF
# BASE.TIIDOCRF
# Document Rev Data - TIDDRHOF
# BASE.TIIDRHO1
# Document Record Data - TIDDOHOF
# BASE.TIIDOHO1
# c:\Users\mounsl\OneDrive - Idaho National Laboratory\Documents - GRP-Agree Data Assessment Team\Asset Suite\Working documents - Start here\DataDictionary_WM.xlsx
# Complex Code Cat - TIDCXCAT
# BASE.TIICXCAT
# Complex Code - TIDCXCDE
# BASE.TIICXCDE
# Cmplx Code Value - TIDCXCDV
# BASE.TIICXCDV
# Cmplx Code Sub Cat - TIDCXSCT
# BASE.TIICXSCT
# Assessment Hdr - TIDRAHDR
# BASE.TIIRAHDR
# Assessment Detail - TIDRADTL
# BASE.TIIRADTL
# Schedule Info - TIDSCHIN
# BASE.TIISCHIN
# General Schedule Info -TIDSCHCP
# BASE.TIISCHCP
# Schedule Person Assign-TIDSCHPA
# BASE.TIISCHPA
# Rsrc Daily Assign - TIDSCHCR
# BASE.TIISCHCR
# Crew Planning - TIDSCHCW
# BASE.TIISCHC3
# Crew Daily Assign - TIDSCHDA
# BASE.TIISCHD1
# Resource Planning - TIDSCHRC
# BASE.TIISCHRC
# Resource Code - TIDRESRC
# BASE.TIIRESRC
# Ref Cost Est - TIDRFEST
# BASE.TIIRFEST
# Ref Mapped Actuals - TIDRFMPA
# BASE.TIIRFMPA
# Ref Mapped Estimate - TIDRFMPE
# BASE.TIIRFMPE
# Hold Codes - TIDRFHLD
# BASE.TIIRFHLD
# Work Order - TIDWOWRK
# BASE.TIIWOWR4
# Work Order Task - TIDWOTSK
# BASE.TIIWOTS1
# WO Task Requirements - TIDWOTRQ
# BASE.TIIWOTRQ
# WO Status Tracking - TIDWOSTR
# BASE.TIIWOST1
# WO Summary - TIDWOSUM
# BASE.TIIWOSUM
# WO Action Comments - TIDWOARC
# BASE.TIIWOARC
# WO Action Request - TIDWOARQ
# BASE.TIIWOARQ
# WO Action Request Tsk -TIDWOART
# BASE.TIIWOAR1
# WO Usage Readings -TIDWOPMU
# BASE.TIIWOPM1
# WO QC Require -TIDWOQCR
# BASE.TIIWOQCR
# WO Contracts -TIDWOSOR
# BASE.TIIWOSOR
# WO Task Comments - TIDWOTCM
# BASE.TIIWOTCM
# WO Completion Comments-TIDWOTCC
# BASE.TIIWOTCC
# WO Task Work Standard -TIDWOSTD
# BASE.TIIWOSTD
# WO Delay Dtl - TIDWOTDL
# BASE.TIIWOTDL
# WO Task Permit Data - TIDWOTPT
# BASE.TIIWOTPT
# WO Stds and Procs - TIDWOTSP
# BASE.TIIWOTS8
# Work Request Header - TIDWRREQ
# BASE.TIIWRREQ
# WR Status Tracking - TIDWRSTR
# BASE.TIIWRST1
# WR Special Requirement-TIDWRRQM
# BASE.TIIWRRQM
# WR Comments -TIDWRCOM
# BASE.TIIWRCOM
# MR Master - TIDMRMST
# BASE.TIIMRMS1
# MR Details - TIDMRDTL
# BASE.TIIMRDTL
# MR Line Dtl - TIDMRRQS
# BASE.TIIMRRQS
# MR Comments - TIDMRCOM
# BASE.TIIMRCOM
# XRef Relationship - TIDXREFR
# BASE.TIIXREFR

# %%
# as_pks.to_excel(path+'Asset Suite-PKs.xlsx', index=False)

# %%
first_pks = as_pks[as_pks['ORDINAL_POSITION']==1].groupby('TableName')['SchemaName'].count()
repeat = first_pks[first_pks>1].index.to_list()

# %%
## XXX Manually decide which create index statement to use on the following tables:
repeat

# %% [markdown]
# # P6 Key "Query"

# %%
# p6_path = 'C:\\Users\\mounsl\\OneDrive - Idaho National Laboratory\Documents - GRP-Agree Data Assessment Team\\Project Management\\3. Data and modeling\\Data Dictionary\\P6\\PXRPTUSER Scripted Views\\'
# p6files = glob.glob(p6_path + '*vw.txt')


# table_pattern = re.compile(r'(?<=C:\\Users\\mounsl\\OneDrive - Idaho National Laboratory\\Documents - GRP-Agree Data Assessment Team\\Project Management\\3\. Data and modeling\\Data Dictionary\\P6\\PXRPTUSER Scripted Views\\).*(?=vw\.txt)')
# pk_pattern = re.compile(r'(?<=[ \.])objectid')  ## TODO: this is selecting the a.name_id portion, need to select the alias and UPPERCASE it
# fk_pattern = re.compile(r'(?<=[/. ])\w+(?=objectid)')
# p6_pks = pd.DataFrame(columns=['SchemaName','TableName','ColumnName','PK_name','ORDINAL_POSITION'])
# p6_fks = pd.DataFrame(columns=['SchemaName','TableName','ColumnName','FK_name','ReferencedTable','ReferencedColumn'])
# for file in p6files:
#     with open(file, 'r') as fp:
#         tableName = table_pattern.search(file)[0]
#         # print(tableName)
#     # read all lines using readline()
#         lines = fp.readlines()
#         j=1
#         for row in lines:
#             # check if string present on a current line
#             if pk_pattern.search(row):
#                 # pk_name = pk_pattern.search(row)[0].upper()
#                 # print('PK for '+tableName+': '+ pk_name)
#                 p6_pks.loc[len(p6_pks)] = {'TableName':tableName,'ColumnName':'OBJECTID','ORDINAL_POSITION':j}
#                 j +=1
#             if fk_pattern.search(row):
#                 fk_table = fk_pattern.search(row)[0].upper()
#                 # print('FK for '+tableName+': '+ fk_table)
#                 p6_fks.loc[len(p6_fks)] = {'TableName':tableName,'ColumnName':fk_table+'OBJECTID','ReferencedTable':fk_table,'ReferencedColumn':'OBJECTID'}

# %%
# p6_pks.to_excel(path+'P6-PKs.xlsx', index=False)
# p6_fks.to_excel(path+'P6-FKs.xlsx', index=False)

# %% [markdown]
# # Validation

# %%
# as_pks[as_pks['ORDINAL_POSITION']==1]['TableName'].nunique()

# %%
## Tables in the DD
dd_gloss['TABLENAME'].nunique()
# Out:
# 306

# %%
## Tables with PK identified
dd_gloss[dd_gloss['Primary Key']==1]['TABLENAME'].nunique()
# Out:
# 255

# %%
## Tables with no PK identified
no_pks = dd_gloss.groupby('TABLENAME').filter(lambda x: x['Primary Key'].isnull().all())

# %%
no_pks.groupby(['System','TABLENAME']).max('Primary Key')#.to_clipboard()
# Out:
#                                        Cardinality  Max Length  Primary Key
# System       TABLENAME
# COBRA        BDNDETL                          21.0         NaN          NaN
#              COB_NTX                          10.0         NaN          NaN
# EDMS         A_DRAFTERS                        8.0        20.0          NaN
#              A_DRAWINGS                    63863.0       800.0          NaN
#              CLOSED_DARS                  247706.0        50.0          NaN
#              DRAW_NUMBERING               245491.0       100.0          NaN
#              DRF                          115002.0      1955.0          NaN
#              ENGINEERS                        30.0        23.0          NaN
#              ERROR_LOG                        24.0       147.0          NaN
#              ESSENTIAL_AREA                 1510.0        15.0          NaN
#              ESSENTIAL_LOG                 17053.0        23.0          NaN
#              MARKUPTAB                         1.0       567.0          NaN
#              OLD_CAD                       76069.0        33.0          NaN
#              SPECIAL_CODES                150472.0        17.0          NaN
#              SPECIAL_CODES_LOG              8297.0        23.0          NaN
#              STW_DRAWINGS                  63131.0        30.0          NaN
#              SUPERSEDED_DRAWINGS           15815.0        10.0          NaN
# IPS          CNCodeImports                    76.0        27.0          NaN
#              datWBS_INL                     6679.0        65.0          NaN
#              dat_MRSendClick                   1.0         NaN          NaN
# P6           ACTIVITYCODEASSIGNMENT       145386.0       120.0          NaN
#              ACTIVITYCODEHEIRARCHY        184726.0       116.0          NaN
#              ACTIVITYSPREAD               145386.0       120.0          NaN
#              COSTACCOUNTHIERARCHY         183484.0        43.0          NaN
#              CURRENCY                      56115.0       120.0          NaN
#              EPSHIERARCHY                 183484.0        43.0          NaN
#              FINANCIALPERIOD               56115.0       120.0          NaN
#              GLOBALPROFILE                 56115.0       120.0          NaN
#              GLOBALSECURITY                  235.0         1.0          NaN
#              PROJECTCODEASSIGNMENT         56115.0       100.0          NaN
#              PROJECTCODEHIERARCHY         184726.0       116.0          NaN
#              PROJECTETLLIST                 1252.0         NaN          NaN
#              PROJECTPROJECTPORTFOLIO       56115.0        10.0          NaN
#              PXSERVICES                    56115.0        98.0          NaN
#              PXSETTINGS                    56115.0      3997.0          NaN
#              RELATIONSHIP                1754511.0       120.0          NaN
#              RESOURCEACCESS                 3088.0        63.0          NaN
#              RESOURCEASSIGNMENTSPREAD     145386.0         NaN          NaN
#              RESOURCECODEASSIGNMENT        56115.0        63.0          NaN
#              RESOURCECODEHIERARCHY        184726.0       116.0          NaN
#              RESOURCEHIERARCHY            183484.0        43.0          NaN
#              RESOURCERESOURCETEAM          56115.0        10.0          NaN
#              UDFTYPE                       56115.0        70.0          NaN
#              UDFVALUE                     217874.0       255.0          NaN
#              USERMODULEACCESS              56115.0        15.0          NaN
#              USERPROFILEPRIVILEGE          56115.0        76.0          NaN
#              WBSHEIRARCHY                 183484.0        43.0          NaN
# Site People  SitePeople                    11452.0        50.0          NaN
#              ntusers                       12216.0        42.0          NaN
# Time Billing PS_IF_BALANCES               163185.0         6.0          NaN
